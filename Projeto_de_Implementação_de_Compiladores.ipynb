# %%
import re
import sys
from collections import defaultdict

# ==============================================================================
# 1. ANALISADOR LÉXICO (SCANNER)
# ==============================================================================
class Lexer:
    def __init__(self, code):
        self.code = code
        self.token_specs = [
            ('MAIN',   r'\bmain\b'),
            ('INT',    r'\bint\b'),
            ('FLOAT',  r'\bfloat\b'),
            ('DOUBLE', r'\bdouble\b'),
            ('CHAR',   r'\bchar\b'),
            ('BOOL',   r'\bbool\b'),
            ('STRING', r'\bstring\b'),

            ('IF',     r'\bif\b'),
            ('ELSE',   r'\belse\b'),
            ('WHILE',  r'\bwhile\b'),
            ('DO',     r'\bdo\b'),
            ('FOR',    r'\bfor\b'),
            ('SWITCH', r'\bswitch\b'),
            ('CASE',   r'\bcase\b'),
            ('DEFAULT',r'\bdefault\b'),
            ('BREAK',  r'\bbreak\b'),
            ('RETURN', r'\breturn\b'),

            ('COMMENT', r'//.*'),

            ('EQ',     r'=='),
            ('NEQ',    r'!='),
            ('LTE',    r'<=' ),
            ('GTE',    r'>=' ),
            ('AND',    r'&&'),
            ('OR',     r'\|\|'),

            ('LT',     r'<'),
            ('GT',     r'>'),
            ('NOT',    r'!'),

            ('PLUS',   r'\+'),
            ('MINUS',  r'-'),
            ('MULT',   r'\*'),
            ('DIV',    r'/'),
            ('MOD',    r'%'),
            ('ASSIGN', r'='),

            ('LPAREN', r'\('),
            ('RPAREN', r'\)'),
            ('LCURLY', r'\{'),
            ('RCURLY', r'\}'),
            ('SEMI',   r';'),
            ('COMMA',  r','),
            ('COLON',  r':'),

            # ==============================
            #   LITERAIS
            # ==============================

            ('CHAR_LITERAL',   r"'([^'\\]|\\.)'"),
            ('STRING_LITERAL', r'"([^"\\]|\\.)*"'),
            ('BOOL_LITERAL',   r'\b(true|false)\b'),

            ('NUMBER', r'\d+(\.\d+)?'),
            ('ID',     r'[a-zA-Z_][a-zA-Z_0-9]*'),

            ('WS',     r'\s+'),
            ('MISMATCH', r'.'),
        ]

    def tokenize(self):
        tokens = []
        token_regex = '|'.join(f'(?P<{pair[0]}>{pair[1]})' for pair in self.token_specs)

        line_num = 1

        for match in re.finditer(token_regex, self.code):
            kind = match.lastgroup
            value = match.group()

            if kind == 'WS':
                line_num += value.count('\n')
                continue
            elif kind == 'MISMATCH':
                print(f"ERRO LÉXICO: Caractere inesperado '{value}' na linha {line_num}")
                sys.exit(1)
            elif kind == 'COMMENT':
                continue
            else:
                tokens.append((kind, value))

        tokens.append(('EOF', '$'))
        return tokens

# ==============================================================================
# 2. GRAMÁTICA LL(1)
# ==============================================================================

grammar = {
    'PROGRAM': [['MAIN_FUNCTION', 'EOF']],

    'MAIN_FUNCTION': [['MAIN', 'LPAREN', 'RPAREN', 'LCURLY', 'STATEMENT_LIST', 'RCURLY']],

    'STATEMENT_LIST': [
        ['STATEMENT', 'STATEMENT_LIST'],
        ['EPSILON']
    ],

    'STATEMENT': [
        ['DECLARATION'],
        ['IF_STATEMENT'],
        ['WHILE_STATEMENT'],
        ['DO_WHILE_STATEMENT'],
        ['FOR_STATEMENT'],
        ['SWITCH_STATEMENT'],
        ['RETURN_STATEMENT'],
        ['STATEMENT_ID_START']
    ],

    'STATEMENT_ID_START': [
        ['ID', 'STATEMENT_ID_TAIL']
    ],

    'STATEMENT_ID_TAIL': [
        ['ASSIGN', 'EXPRESSION', 'SEMI'],
        ['TERM_PRIME', 'EXP_PRIME', 'SEMI']
    ],

    'DECLARATION': [['TYPE', 'ID', 'DECLARATION_TAIL']],

    'DECLARATION_TAIL': [
        ['ASSIGN', 'EXPRESSION', 'SEMI'],
        ['SEMI']
    ],

    'TYPE': [['INT'], ['FLOAT'], ['DOUBLE'], ['CHAR'], ['BOOL'], ['STRING']],

    'IF_STATEMENT': [['IF', 'LPAREN', 'CONDITION', 'RPAREN', 'LCURLY', 'STATEMENT_LIST', 'RCURLY', 'ELSE_CLAUSE']],

    'ELSE_CLAUSE': [
        ['ELSE', 'LCURLY', 'STATEMENT_LIST', 'RCURLY'],
        ['EPSILON']
    ],

    'WHILE_STATEMENT': [['WHILE', 'LPAREN', 'CONDITION', 'RPAREN', 'LCURLY', 'STATEMENT_LIST', 'RCURLY']],

    'DO_WHILE_STATEMENT': [
        ['DO', 'LCURLY', 'STATEMENT_LIST', 'RCURLY', 'WHILE', 'LPAREN', 'CONDITION', 'RPAREN', 'SEMI']
    ],

    'FOR_STATEMENT': [['FOR', 'LPAREN', 'FOR_INIT', 'SEMI', 'CONDITION', 'SEMI', 'FOR_UPDATE', 'RPAREN', 'LCURLY', 'STATEMENT_LIST', 'RCURLY']],

    'FOR_INIT': [['DECLARATION'], ['ASSIGNMENT'], ['EPSILON']],
    'ASSIGNMENT': [['ID', 'ASSIGN', 'EXPRESSION']],
    'FOR_UPDATE': [['ID', 'ASSIGN', 'EXPRESSION'], ['EPSILON']],

    # ==============================
    # SWITCH CORRIGIDO
    # ==============================

    'SWITCH_STATEMENT': [
        ['SWITCH', 'LPAREN', 'EXPRESSION', 'RPAREN', 'LCURLY', 'CASE_LIST', 'RCURLY']
    ],

    'CASE_LIST': [
        ['CASE', 'LITERAL', 'COLON', 'STATEMENT_LIST', 'BREAK', 'SEMI', 'CASE_LIST'],
        ['DEFAULT', 'COLON', 'STATEMENT_LIST', 'BREAK', 'SEMI'],
        ['EPSILON']
    ],

    'LITERAL': [
        ['NUMBER'],
        ['CHAR_LITERAL'],
        ['STRING_LITERAL'],
        ['BOOL_LITERAL']
    ],

    'RETURN_STATEMENT': [['RETURN', 'RETURN_TAIL']],

    'RETURN_TAIL': [['EXPRESSION', 'SEMI'], ['SEMI']],

    'CONDITION': [['LOGICAL_OR_EXPR']],

    'LOGICAL_OR_EXPR': [['LOGICAL_AND_EXPR', 'LOGICAL_OR_PRIME']],
    'LOGICAL_OR_PRIME': [['OR', 'LOGICAL_AND_EXPR', 'LOGICAL_OR_PRIME'], ['EPSILON']],

    'LOGICAL_AND_EXPR': [['RELATIONAL_EXPR', 'LOGICAL_AND_PRIME']],
    'LOGICAL_AND_PRIME': [['AND', 'RELATIONAL_EXPR', 'LOGICAL_AND_PRIME'], ['EPSILON']],

    'RELATIONAL_EXPR': [['EXPRESSION', 'RELATIONAL_TAIL'], ['NOT', 'RELATIONAL_EXPR']],

    'RELATIONAL_TAIL': [
        ['EQ', 'EXPRESSION'], ['NEQ', 'EXPRESSION'],
        ['LT', 'EXPRESSION'], ['GT', 'EXPRESSION'],
        ['LTE', 'EXPRESSION'], ['GTE', 'EXPRESSION'],
        ['EPSILON']
    ],

    'EXPRESSION': [['TERM', 'EXP_PRIME']],

    'EXP_PRIME': [
        ['PLUS', 'TERM', 'EXP_PRIME'],
        ['MINUS', 'TERM', 'EXP_PRIME'],
        ['EPSILON']
    ],

    'TERM': [['FACTOR', 'TERM_PRIME']],

    'TERM_PRIME': [
        ['MULT', 'FACTOR', 'TERM_PRIME'],
        ['DIV', 'FACTOR', 'TERM_PRIME'],
        ['MOD', 'FACTOR', 'TERM_PRIME'],
        ['EPSILON']
    ],

    'FACTOR': [
        ['ID'],
        ['NUMBER'],
        ['CHAR_LITERAL'],
        ['STRING_LITERAL'],
        ['BOOL_LITERAL'],
        ['LPAREN', 'EXPRESSION', 'RPAREN'],
        ['MINUS', 'FACTOR']
    ]
}

terminals = {
    'MAIN', 'INT', 'FLOAT', 'DOUBLE','CHAR', 'BOOL', 'STRING',
    'CHAR_LITERAL', 'STRING_LITERAL', 'BOOL_LITERAL',
    'IF', 'ELSE', 'WHILE', 'DO', 'FOR',
    'SWITCH', 'CASE', 'DEFAULT', 'BREAK',
    'RETURN', 'COMMENT',
    'ID', 'NUMBER', 'PLUS', 'MINUS', 'MULT', 'DIV', 'MOD', 'ASSIGN',
    'EQ', 'NEQ', 'LT', 'GT', 'LTE', 'GTE', 'AND', 'OR', 'NOT',
    'LPAREN', 'RPAREN', 'LCURLY', 'RCURLY', 'SEMI', 'COMMA', 'COLON', 'EOF'
}
non_terminals = set(grammar.keys())

# ==============================================================================
# 3. FIRST, FOLLOW, TABELA PREDITIVA
# ==============================================================================

first = defaultdict(set)
follow = defaultdict(set)
parsing_table = {}

def compute_first():
    global first
    for t in terminals:
        first[t].add(t)
    first['EPSILON'].add('EPSILON')

    changed = True
    while changed:
        changed = False
        for head, productions in grammar.items():
            for prod in productions:
                can_be_empty = True
                for symbol in prod:
                    initial_len = len(first[head])
                    s_first = first[symbol].copy()
                    if 'EPSILON' in s_first:
                        s_first.remove('EPSILON')
                    else:
                        can_be_empty = False
                    first[head].update(s_first)
                    if len(first[head]) > initial_len:
                        changed = True
                    if not can_be_empty:
                        break
                if can_be_empty:
                    if 'EPSILON' not in first[head]:
                        first[head].add('EPSILON')
                        changed = True

def compute_follow():
    global follow
    follow['PROGRAM'].add('$')
    changed = True
    while changed:
        changed = False
        for head, productions in grammar.items():
            for prod in productions:
                trailer = follow[head].copy()
                for symbol in reversed(prod):
                    if symbol in non_terminals:
                        initial_len = len(follow[symbol])
                        follow[symbol].update(trailer)
                        if len(follow[symbol]) > initial_len:
                            changed = True
                        if 'EPSILON' in first[symbol]:
                            trailer.update(first[symbol])
                            trailer.remove('EPSILON')
                        else:
                            trailer = first[symbol].copy()
                    else:
                        trailer = first[symbol].copy()

def build_parsing_table():
    global parsing_table
    for head, productions in grammar.items():
        for prod in productions:
            prod_first = set()
            can_be_empty = True
            for symbol in prod:
                s_first = first[symbol].copy()
                if 'EPSILON' in s_first:
                    s_first.remove('EPSILON')
                else:
                    can_be_empty = False
                prod_first.update(s_first)
                if not can_be_empty:
                    break

            for terminal in prod_first:
                parsing_table[(head, terminal)] = prod

            if can_be_empty or (len(prod) == 1 and prod[0] == 'EPSILON'):
                for terminal in follow[head]:
                    parsing_table[(head, terminal)] = prod

# ==============================================================================
# 4. PARSER MANUAL COM PILHA
# ==============================================================================

def parse(tokens):
    stack = ['PROGRAM']
    cursor = 0

    print(f"\n{'PILHA':<70} | {'ENTRADA':<20} | AÇÃO")
    print("-" * 110)

    while len(stack) > 0:
        top = stack[-1]

        if cursor >= len(tokens):
            print("ERRO CRÍTICO: Tentativa de ler além do fim.")
            return False

        token_type = tokens[cursor][0]
        token_val = tokens[cursor][1]
        stack_str = " ".join(stack)

        if top == token_type:
            if top == 'EOF':
                print(f"{stack_str:<70} | {token_val:<20} | SUCESSO: ACEITO")
                return True

            print(f"{stack_str:<70} | {token_val:<20} | Ler {top}")
            stack.pop()
            cursor += 1

        elif top == 'EPSILON':
            print(f"{stack_str:<70} | {token_val:<20} | Epsilon")
            stack.pop()

        elif top in terminals:
            print(f"\nERRO: Esperado '{top}', encontrado '{token_val}'")
            return False

        elif (top, token_type) in parsing_table:
            prod = parsing_table[(top, token_type)]
            print(f"{stack_str:<70} | {token_val:<20} | {top} -> {' '.join(prod)}")
            stack.pop()
            for symbol in reversed(prod):
                stack.append(symbol)

        else:
            print(f"\nERRO: Sem regra para {top} com {token_type}")
            return False

    return True

# %%
# ==============================================================================
# 1. ✔ SUCESSO – CÓDIGO ACEITO
# ==============================================================================
if __name__ == "__main__":

    codigo_teste = """
   main() {

    // =======================
    // DECLARAÇÕES
    // =======================
    int a = 10;
    int b = 20;
    bool flag = true;
    char letra = 'x';
    string msg = "teste";
    float x = 3.5;

    // =======================
    // IF / ELSE
    // =======================
    if(a < b) {
        a = a + 1;
    } else {
        b = b + 1;
    }

    // =======================
    // WHILE
    // =======================
    while(a < 15) {
        a = a + 1;
    }

    // =======================
    // DO / WHILE
    // =======================
    do {
        b = b - 1;
    } while(b > 10);

    // =======================
    // FOR
    // =======================
    for(i = 0; i < 5; i = i + 1) {
        x = x * 2;
    }

    // =======================
    // SWITCH / CASE / DEFAULT
    // =======================
    switch(a) {
        case 10:
            msg = "valor 10";
            break;

        case 15:
            msg = "valor 15";
            break;

        default:
            msg = "outro valor";
            break;
    }

    // =======================
    // RETURN
    // =======================
    return a;
}

    """


    print("=== 1. LEXER ===")
    lexer = Lexer(codigo_teste)
    tokens = lexer.tokenize()
    print("Tokens OK.")

    print("\n=== 2. TABLE ===")
    compute_first()
    compute_follow()
    build_parsing_table()
    print("Tabela OK.")

    print("\n=== 3. PARSER ===")
    parse(tokens)
# Out:
# === 1. LEXER ===
# Tokens OK.
#
# === 2. TABLE ===
# Tabela OK.
#
# === 3. PARSER ===
#
# PILHA                                                                  | ENTRADA              | AÇÃO
# --------------------------------------------------------------------------------------------------------------
# PROGRAM                                                                | main                 | PROGRAM -> MAIN_FUNCTION EOF
# EOF MAIN_FUNCTION                                                      | main                 | MAIN_FUNCTION -> MAIN LPAREN RPAREN LCURLY STATEMENT_LIST RCURLY
# EOF RCURLY STATEMENT_LIST LCURLY RPAREN LPAREN MAIN                    | main                 | Ler MAIN
# EOF RCURLY STATEMENT_LIST LCURLY RPAREN LPAREN                         | (                    | Ler LPAREN
# EOF RCURLY STATEMENT_LIST LCURLY RPAREN                                | )                    | Ler RPAREN
# EOF RCURLY STATEMENT_LIST LCURLY                                       | {                    | Ler LCURLY
# EOF RCURLY STATEMENT_LIST                                              | int                  | STATEMENT_LIST -> STATEMENT STATEMENT_LIST
# EOF RCURLY STATEMENT_LIST STATEMENT                                    | int                  | STATEMENT -> DECLARATION
# EOF RCURLY STATEMENT_LIST DECLARATION                                  | int                  | DECLARATION -> TYPE ID DECLARATION_TAIL
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL ID TYPE                     | int                  | TYPE -> INT
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL ID INT                      | int                  | Ler INT
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL ID                          | a                    | Ler ID
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL                             | =                    | DECLARATION_TAIL -> ASSIGN EXPRESSION SEMI
# EOF RCURLY STATEMENT_LIST SEMI EXPRESSION ASSIGN                       | =                    | Ler ASSIGN
# EOF RCURLY STATEMENT_LIST SEMI EXPRESSION                              | 10                   | EXPRESSION -> TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM                          | 10                   | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME FACTOR             | 10                   | FACTOR -> NUMBER
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME NUMBER             | 10                   | Ler NUMBER
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME                    | ;                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME EPSILON                       | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME                               | ;                    | EXP_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST SEMI EPSILON                                 | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST SEMI                                         | ;                    | Ler SEMI
# EOF RCURLY STATEMENT_LIST                                              | int                  | STATEMENT_LIST -> STATEMENT STATEMENT_LIST
# EOF RCURLY STATEMENT_LIST STATEMENT                                    | int                  | STATEMENT -> DECLARATION
# EOF RCURLY STATEMENT_LIST DECLARATION                                  | int                  | DECLARATION -> TYPE ID DECLARATION_TAIL
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL ID TYPE                     | int                  | TYPE -> INT
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL ID INT                      | int                  | Ler INT
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL ID                          | b                    | Ler ID
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL                             | =                    | DECLARATION_TAIL -> ASSIGN EXPRESSION SEMI
# EOF RCURLY STATEMENT_LIST SEMI EXPRESSION ASSIGN                       | =                    | Ler ASSIGN
# EOF RCURLY STATEMENT_LIST SEMI EXPRESSION                              | 20                   | EXPRESSION -> TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM                          | 20                   | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME FACTOR             | 20                   | FACTOR -> NUMBER
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME NUMBER             | 20                   | Ler NUMBER
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME                    | ;                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME EPSILON                       | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME                               | ;                    | EXP_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST SEMI EPSILON                                 | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST SEMI                                         | ;                    | Ler SEMI
# EOF RCURLY STATEMENT_LIST                                              | bool                 | STATEMENT_LIST -> STATEMENT STATEMENT_LIST
# EOF RCURLY STATEMENT_LIST STATEMENT                                    | bool                 | STATEMENT -> DECLARATION
# EOF RCURLY STATEMENT_LIST DECLARATION                                  | bool                 | DECLARATION -> TYPE ID DECLARATION_TAIL
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL ID TYPE                     | bool                 | TYPE -> BOOL
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL ID BOOL                     | bool                 | Ler BOOL
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL ID                          | flag                 | Ler ID
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL                             | =                    | DECLARATION_TAIL -> ASSIGN EXPRESSION SEMI
# EOF RCURLY STATEMENT_LIST SEMI EXPRESSION ASSIGN                       | =                    | Ler ASSIGN
# EOF RCURLY STATEMENT_LIST SEMI EXPRESSION                              | true                 | EXPRESSION -> TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM                          | true                 | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME FACTOR             | true                 | FACTOR -> BOOL_LITERAL
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME BOOL_LITERAL       | true                 | Ler BOOL_LITERAL
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME                    | ;                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME EPSILON                       | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME                               | ;                    | EXP_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST SEMI EPSILON                                 | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST SEMI                                         | ;                    | Ler SEMI
# EOF RCURLY STATEMENT_LIST                                              | char                 | STATEMENT_LIST -> STATEMENT STATEMENT_LIST
# EOF RCURLY STATEMENT_LIST STATEMENT                                    | char                 | STATEMENT -> DECLARATION
# EOF RCURLY STATEMENT_LIST DECLARATION                                  | char                 | DECLARATION -> TYPE ID DECLARATION_TAIL
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL ID TYPE                     | char                 | TYPE -> CHAR
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL ID CHAR                     | char                 | Ler CHAR
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL ID                          | letra                | Ler ID
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL                             | =                    | DECLARATION_TAIL -> ASSIGN EXPRESSION SEMI
# EOF RCURLY STATEMENT_LIST SEMI EXPRESSION ASSIGN                       | =                    | Ler ASSIGN
# EOF RCURLY STATEMENT_LIST SEMI EXPRESSION                              | 'x'                  | EXPRESSION -> TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM                          | 'x'                  | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME FACTOR             | 'x'                  | FACTOR -> CHAR_LITERAL
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME CHAR_LITERAL       | 'x'                  | Ler CHAR_LITERAL
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME                    | ;                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME EPSILON                       | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME                               | ;                    | EXP_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST SEMI EPSILON                                 | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST SEMI                                         | ;                    | Ler SEMI
# EOF RCURLY STATEMENT_LIST                                              | string               | STATEMENT_LIST -> STATEMENT STATEMENT_LIST
# EOF RCURLY STATEMENT_LIST STATEMENT                                    | string               | STATEMENT -> DECLARATION
# EOF RCURLY STATEMENT_LIST DECLARATION                                  | string               | DECLARATION -> TYPE ID DECLARATION_TAIL
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL ID TYPE                     | string               | TYPE -> STRING
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL ID STRING                   | string               | Ler STRING
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL ID                          | msg                  | Ler ID
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL                             | =                    | DECLARATION_TAIL -> ASSIGN EXPRESSION SEMI
# EOF RCURLY STATEMENT_LIST SEMI EXPRESSION ASSIGN                       | =                    | Ler ASSIGN
# EOF RCURLY STATEMENT_LIST SEMI EXPRESSION                              | "teste"              | EXPRESSION -> TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM                          | "teste"              | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME FACTOR             | "teste"              | FACTOR -> STRING_LITERAL
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME STRING_LITERAL     | "teste"              | Ler STRING_LITERAL
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME                    | ;                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME EPSILON                       | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME                               | ;                    | EXP_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST SEMI EPSILON                                 | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST SEMI                                         | ;                    | Ler SEMI
# EOF RCURLY STATEMENT_LIST                                              | float                | STATEMENT_LIST -> STATEMENT STATEMENT_LIST
# EOF RCURLY STATEMENT_LIST STATEMENT                                    | float                | STATEMENT -> DECLARATION
# EOF RCURLY STATEMENT_LIST DECLARATION                                  | float                | DECLARATION -> TYPE ID DECLARATION_TAIL
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL ID TYPE                     | float                | TYPE -> FLOAT
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL ID FLOAT                    | float                | Ler FLOAT
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL ID                          | x                    | Ler ID
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL                             | =                    | DECLARATION_TAIL -> ASSIGN EXPRESSION SEMI
# EOF RCURLY STATEMENT_LIST SEMI EXPRESSION ASSIGN                       | =                    | Ler ASSIGN
# EOF RCURLY STATEMENT_LIST SEMI EXPRESSION                              | 3.5                  | EXPRESSION -> TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM                          | 3.5                  | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME FACTOR             | 3.5                  | FACTOR -> NUMBER
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME NUMBER             | 3.5                  | Ler NUMBER
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME                    | ;                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME EPSILON                       | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME                               | ;                    | EXP_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST SEMI EPSILON                                 | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST SEMI                                         | ;                    | Ler SEMI
# EOF RCURLY STATEMENT_LIST                                              | if                   | STATEMENT_LIST -> STATEMENT STATEMENT_LIST
# EOF RCURLY STATEMENT_LIST STATEMENT                                    | if                   | STATEMENT -> IF_STATEMENT
# EOF RCURLY STATEMENT_LIST IF_STATEMENT                                 | if                   | IF_STATEMENT -> IF LPAREN CONDITION RPAREN LCURLY STATEMENT_LIST RCURLY ELSE_CLAUSE
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST LCURLY RPAREN CONDITION LPAREN IF | if                   | Ler IF
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST LCURLY RPAREN CONDITION LPAREN | (                    | Ler LPAREN
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST LCURLY RPAREN CONDITION | a                    | CONDITION -> LOGICAL_OR_EXPR
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_EXPR | a                    | LOGICAL_OR_EXPR -> LOGICAL_AND_EXPR LOGICAL_OR_PRIME
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_EXPR | a                    | LOGICAL_AND_EXPR -> RELATIONAL_EXPR LOGICAL_AND_PRIME
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_EXPR | a                    | RELATIONAL_EXPR -> EXPRESSION RELATIONAL_TAIL
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXPRESSION | a                    | EXPRESSION -> TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXP_PRIME TERM | a                    | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXP_PRIME TERM_PRIME FACTOR | a                    | FACTOR -> ID
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXP_PRIME TERM_PRIME ID | a                    | Ler ID
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXP_PRIME TERM_PRIME | <                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXP_PRIME EPSILON | <                    | Epsilon
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXP_PRIME | <                    | EXP_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EPSILON | <                    | Epsilon
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL | <                    | RELATIONAL_TAIL -> LT EXPRESSION
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXPRESSION LT | <                    | Ler LT
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXPRESSION | b                    | EXPRESSION -> TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXP_PRIME TERM | b                    | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXP_PRIME TERM_PRIME FACTOR | b                    | FACTOR -> ID
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXP_PRIME TERM_PRIME ID | b                    | Ler ID
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXP_PRIME TERM_PRIME | )                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXP_PRIME EPSILON | )                    | Epsilon
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXP_PRIME | )                    | EXP_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EPSILON | )                    | Epsilon
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME | )                    | LOGICAL_AND_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME EPSILON | )                    | Epsilon
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME | )                    | LOGICAL_OR_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST LCURLY RPAREN EPSILON | )                    | Epsilon
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST LCURLY RPAREN | )                    | Ler RPAREN
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST LCURLY     | {                    | Ler LCURLY
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST            | a                    | STATEMENT_LIST -> STATEMENT STATEMENT_LIST
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST STATEMENT  | a                    | STATEMENT -> STATEMENT_ID_START
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST STATEMENT_ID_START | a                    | STATEMENT_ID_START -> ID STATEMENT_ID_TAIL
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST STATEMENT_ID_TAIL ID | a                    | Ler ID
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST STATEMENT_ID_TAIL | =                    | STATEMENT_ID_TAIL -> ASSIGN EXPRESSION SEMI
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST SEMI EXPRESSION ASSIGN | =                    | Ler ASSIGN
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST SEMI EXPRESSION | a                    | EXPRESSION -> TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM | a                    | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME FACTOR | a                    | FACTOR -> ID
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME ID | a                    | Ler ID
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME | +                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST SEMI EXP_PRIME EPSILON | +                    | Epsilon
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST SEMI EXP_PRIME | +                    | EXP_PRIME -> PLUS TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM PLUS | +                    | Ler PLUS
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM | 1                    | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME FACTOR | 1                    | FACTOR -> NUMBER
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME NUMBER | 1                    | Ler NUMBER
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME | ;                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST SEMI EXP_PRIME EPSILON | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST SEMI EXP_PRIME | ;                    | EXP_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST SEMI EPSILON | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST SEMI       | ;                    | Ler SEMI
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY STATEMENT_LIST            | }                    | STATEMENT_LIST -> EPSILON
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY EPSILON                   | }                    | Epsilon
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE RCURLY                           | }                    | Ler RCURLY
# EOF RCURLY STATEMENT_LIST ELSE_CLAUSE                                  | else                 | ELSE_CLAUSE -> ELSE LCURLY STATEMENT_LIST RCURLY
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY ELSE            | else                 | Ler ELSE
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY                 | {                    | Ler LCURLY
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST                        | b                    | STATEMENT_LIST -> STATEMENT STATEMENT_LIST
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST STATEMENT              | b                    | STATEMENT -> STATEMENT_ID_START
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST STATEMENT_ID_START     | b                    | STATEMENT_ID_START -> ID STATEMENT_ID_TAIL
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST STATEMENT_ID_TAIL ID   | b                    | Ler ID
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST STATEMENT_ID_TAIL      | =                    | STATEMENT_ID_TAIL -> ASSIGN EXPRESSION SEMI
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXPRESSION ASSIGN | =                    | Ler ASSIGN
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXPRESSION        | b                    | EXPRESSION -> TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM    | b                    | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME FACTOR | b                    | FACTOR -> ID
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME ID | b                    | Ler ID
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME | +                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME EPSILON | +                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME         | +                    | EXP_PRIME -> PLUS TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM PLUS | +                    | Ler PLUS
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM    | 1                    | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME FACTOR | 1                    | FACTOR -> NUMBER
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME NUMBER | 1                    | Ler NUMBER
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME | ;                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME EPSILON | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME         | ;                    | EXP_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EPSILON           | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI                   | ;                    | Ler SEMI
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST                        | }                    | STATEMENT_LIST -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY EPSILON                               | }                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY                                       | }                    | Ler RCURLY
# EOF RCURLY STATEMENT_LIST                                              | while                | STATEMENT_LIST -> STATEMENT STATEMENT_LIST
# EOF RCURLY STATEMENT_LIST STATEMENT                                    | while                | STATEMENT -> WHILE_STATEMENT
# EOF RCURLY STATEMENT_LIST WHILE_STATEMENT                              | while                | WHILE_STATEMENT -> WHILE LPAREN CONDITION RPAREN LCURLY STATEMENT_LIST RCURLY
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN CONDITION LPAREN WHILE | while                | Ler WHILE
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN CONDITION LPAREN | (                    | Ler LPAREN
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN CONDITION | a                    | CONDITION -> LOGICAL_OR_EXPR
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_EXPR | a                    | LOGICAL_OR_EXPR -> LOGICAL_AND_EXPR LOGICAL_OR_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_EXPR | a                    | LOGICAL_AND_EXPR -> RELATIONAL_EXPR LOGICAL_AND_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_EXPR | a                    | RELATIONAL_EXPR -> EXPRESSION RELATIONAL_TAIL
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXPRESSION | a                    | EXPRESSION -> TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXP_PRIME TERM | a                    | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXP_PRIME TERM_PRIME FACTOR | a                    | FACTOR -> ID
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXP_PRIME TERM_PRIME ID | a                    | Ler ID
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXP_PRIME TERM_PRIME | <                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXP_PRIME EPSILON | <                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXP_PRIME | <                    | EXP_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EPSILON | <                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL | <                    | RELATIONAL_TAIL -> LT EXPRESSION
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXPRESSION LT | <                    | Ler LT
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXPRESSION | 15                   | EXPRESSION -> TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXP_PRIME TERM | 15                   | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXP_PRIME TERM_PRIME FACTOR | 15                   | FACTOR -> NUMBER
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXP_PRIME TERM_PRIME NUMBER | 15                   | Ler NUMBER
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXP_PRIME TERM_PRIME | )                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXP_PRIME EPSILON | )                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXP_PRIME | )                    | EXP_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EPSILON | )                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME | )                    | LOGICAL_AND_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME EPSILON | )                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME | )                    | LOGICAL_OR_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN EPSILON  | )                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN          | )                    | Ler RPAREN
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY                 | {                    | Ler LCURLY
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST                        | a                    | STATEMENT_LIST -> STATEMENT STATEMENT_LIST
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST STATEMENT              | a                    | STATEMENT -> STATEMENT_ID_START
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST STATEMENT_ID_START     | a                    | STATEMENT_ID_START -> ID STATEMENT_ID_TAIL
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST STATEMENT_ID_TAIL ID   | a                    | Ler ID
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST STATEMENT_ID_TAIL      | =                    | STATEMENT_ID_TAIL -> ASSIGN EXPRESSION SEMI
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXPRESSION ASSIGN | =                    | Ler ASSIGN
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXPRESSION        | a                    | EXPRESSION -> TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM    | a                    | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME FACTOR | a                    | FACTOR -> ID
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME ID | a                    | Ler ID
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME | +                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME EPSILON | +                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME         | +                    | EXP_PRIME -> PLUS TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM PLUS | +                    | Ler PLUS
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM    | 1                    | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME FACTOR | 1                    | FACTOR -> NUMBER
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME NUMBER | 1                    | Ler NUMBER
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME | ;                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME EPSILON | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME         | ;                    | EXP_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EPSILON           | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI                   | ;                    | Ler SEMI
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST                        | }                    | STATEMENT_LIST -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY EPSILON                               | }                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY                                       | }                    | Ler RCURLY
# EOF RCURLY STATEMENT_LIST                                              | do                   | STATEMENT_LIST -> STATEMENT STATEMENT_LIST
# EOF RCURLY STATEMENT_LIST STATEMENT                                    | do                   | STATEMENT -> DO_WHILE_STATEMENT
# EOF RCURLY STATEMENT_LIST DO_WHILE_STATEMENT                           | do                   | DO_WHILE_STATEMENT -> DO LCURLY STATEMENT_LIST RCURLY WHILE LPAREN CONDITION RPAREN SEMI
# EOF RCURLY STATEMENT_LIST SEMI RPAREN CONDITION LPAREN WHILE RCURLY STATEMENT_LIST LCURLY DO | do                   | Ler DO
# EOF RCURLY STATEMENT_LIST SEMI RPAREN CONDITION LPAREN WHILE RCURLY STATEMENT_LIST LCURLY | {                    | Ler LCURLY
# EOF RCURLY STATEMENT_LIST SEMI RPAREN CONDITION LPAREN WHILE RCURLY STATEMENT_LIST | b                    | STATEMENT_LIST -> STATEMENT STATEMENT_LIST
# EOF RCURLY STATEMENT_LIST SEMI RPAREN CONDITION LPAREN WHILE RCURLY STATEMENT_LIST STATEMENT | b                    | STATEMENT -> STATEMENT_ID_START
# EOF RCURLY STATEMENT_LIST SEMI RPAREN CONDITION LPAREN WHILE RCURLY STATEMENT_LIST STATEMENT_ID_START | b                    | STATEMENT_ID_START -> ID STATEMENT_ID_TAIL
# EOF RCURLY STATEMENT_LIST SEMI RPAREN CONDITION LPAREN WHILE RCURLY STATEMENT_LIST STATEMENT_ID_TAIL ID | b                    | Ler ID
# EOF RCURLY STATEMENT_LIST SEMI RPAREN CONDITION LPAREN WHILE RCURLY STATEMENT_LIST STATEMENT_ID_TAIL | =                    | STATEMENT_ID_TAIL -> ASSIGN EXPRESSION SEMI
# EOF RCURLY STATEMENT_LIST SEMI RPAREN CONDITION LPAREN WHILE RCURLY STATEMENT_LIST SEMI EXPRESSION ASSIGN | =                    | Ler ASSIGN
# EOF RCURLY STATEMENT_LIST SEMI RPAREN CONDITION LPAREN WHILE RCURLY STATEMENT_LIST SEMI EXPRESSION | b                    | EXPRESSION -> TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST SEMI RPAREN CONDITION LPAREN WHILE RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM | b                    | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST SEMI RPAREN CONDITION LPAREN WHILE RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME FACTOR | b                    | FACTOR -> ID
# EOF RCURLY STATEMENT_LIST SEMI RPAREN CONDITION LPAREN WHILE RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME ID | b                    | Ler ID
# EOF RCURLY STATEMENT_LIST SEMI RPAREN CONDITION LPAREN WHILE RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME | -                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST SEMI RPAREN CONDITION LPAREN WHILE RCURLY STATEMENT_LIST SEMI EXP_PRIME EPSILON | -                    | Epsilon
# EOF RCURLY STATEMENT_LIST SEMI RPAREN CONDITION LPAREN WHILE RCURLY STATEMENT_LIST SEMI EXP_PRIME | -                    | EXP_PRIME -> MINUS TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST SEMI RPAREN CONDITION LPAREN WHILE RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM MINUS | -                    | Ler MINUS
# EOF RCURLY STATEMENT_LIST SEMI RPAREN CONDITION LPAREN WHILE RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM | 1                    | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST SEMI RPAREN CONDITION LPAREN WHILE RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME FACTOR | 1                    | FACTOR -> NUMBER
# EOF RCURLY STATEMENT_LIST SEMI RPAREN CONDITION LPAREN WHILE RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME NUMBER | 1                    | Ler NUMBER
# EOF RCURLY STATEMENT_LIST SEMI RPAREN CONDITION LPAREN WHILE RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME | ;                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST SEMI RPAREN CONDITION LPAREN WHILE RCURLY STATEMENT_LIST SEMI EXP_PRIME EPSILON | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST SEMI RPAREN CONDITION LPAREN WHILE RCURLY STATEMENT_LIST SEMI EXP_PRIME | ;                    | EXP_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST SEMI RPAREN CONDITION LPAREN WHILE RCURLY STATEMENT_LIST SEMI EPSILON | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST SEMI RPAREN CONDITION LPAREN WHILE RCURLY STATEMENT_LIST SEMI | ;                    | Ler SEMI
# EOF RCURLY STATEMENT_LIST SEMI RPAREN CONDITION LPAREN WHILE RCURLY STATEMENT_LIST | }                    | STATEMENT_LIST -> EPSILON
# EOF RCURLY STATEMENT_LIST SEMI RPAREN CONDITION LPAREN WHILE RCURLY EPSILON | }                    | Epsilon
# EOF RCURLY STATEMENT_LIST SEMI RPAREN CONDITION LPAREN WHILE RCURLY    | }                    | Ler RCURLY
# EOF RCURLY STATEMENT_LIST SEMI RPAREN CONDITION LPAREN WHILE           | while                | Ler WHILE
# EOF RCURLY STATEMENT_LIST SEMI RPAREN CONDITION LPAREN                 | (                    | Ler LPAREN
# EOF RCURLY STATEMENT_LIST SEMI RPAREN CONDITION                        | b                    | CONDITION -> LOGICAL_OR_EXPR
# EOF RCURLY STATEMENT_LIST SEMI RPAREN LOGICAL_OR_EXPR                  | b                    | LOGICAL_OR_EXPR -> LOGICAL_AND_EXPR LOGICAL_OR_PRIME
# EOF RCURLY STATEMENT_LIST SEMI RPAREN LOGICAL_OR_PRIME LOGICAL_AND_EXPR | b                    | LOGICAL_AND_EXPR -> RELATIONAL_EXPR LOGICAL_AND_PRIME
# EOF RCURLY STATEMENT_LIST SEMI RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_EXPR | b                    | RELATIONAL_EXPR -> EXPRESSION RELATIONAL_TAIL
# EOF RCURLY STATEMENT_LIST SEMI RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXPRESSION | b                    | EXPRESSION -> TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST SEMI RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXP_PRIME TERM | b                    | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST SEMI RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXP_PRIME TERM_PRIME FACTOR | b                    | FACTOR -> ID
# EOF RCURLY STATEMENT_LIST SEMI RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXP_PRIME TERM_PRIME ID | b                    | Ler ID
# EOF RCURLY STATEMENT_LIST SEMI RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXP_PRIME TERM_PRIME | >                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST SEMI RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXP_PRIME EPSILON | >                    | Epsilon
# EOF RCURLY STATEMENT_LIST SEMI RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXP_PRIME | >                    | EXP_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST SEMI RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EPSILON | >                    | Epsilon
# EOF RCURLY STATEMENT_LIST SEMI RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL | >                    | RELATIONAL_TAIL -> GT EXPRESSION
# EOF RCURLY STATEMENT_LIST SEMI RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXPRESSION GT | >                    | Ler GT
# EOF RCURLY STATEMENT_LIST SEMI RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXPRESSION | 10                   | EXPRESSION -> TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST SEMI RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXP_PRIME TERM | 10                   | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST SEMI RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXP_PRIME TERM_PRIME FACTOR | 10                   | FACTOR -> NUMBER
# EOF RCURLY STATEMENT_LIST SEMI RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXP_PRIME TERM_PRIME NUMBER | 10                   | Ler NUMBER
# EOF RCURLY STATEMENT_LIST SEMI RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXP_PRIME TERM_PRIME | )                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST SEMI RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXP_PRIME EPSILON | )                    | Epsilon
# EOF RCURLY STATEMENT_LIST SEMI RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXP_PRIME | )                    | EXP_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST SEMI RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EPSILON | )                    | Epsilon
# EOF RCURLY STATEMENT_LIST SEMI RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME | )                    | LOGICAL_AND_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST SEMI RPAREN LOGICAL_OR_PRIME EPSILON         | )                    | Epsilon
# EOF RCURLY STATEMENT_LIST SEMI RPAREN LOGICAL_OR_PRIME                 | )                    | LOGICAL_OR_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST SEMI RPAREN EPSILON                          | )                    | Epsilon
# EOF RCURLY STATEMENT_LIST SEMI RPAREN                                  | )                    | Ler RPAREN
# EOF RCURLY STATEMENT_LIST SEMI                                         | ;                    | Ler SEMI
# EOF RCURLY STATEMENT_LIST                                              | for                  | STATEMENT_LIST -> STATEMENT STATEMENT_LIST
# EOF RCURLY STATEMENT_LIST STATEMENT                                    | for                  | STATEMENT -> FOR_STATEMENT
# EOF RCURLY STATEMENT_LIST FOR_STATEMENT                                | for                  | FOR_STATEMENT -> FOR LPAREN FOR_INIT SEMI CONDITION SEMI FOR_UPDATE RPAREN LCURLY STATEMENT_LIST RCURLY
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI CONDITION SEMI FOR_INIT LPAREN FOR | for                  | Ler FOR
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI CONDITION SEMI FOR_INIT LPAREN | (                    | Ler LPAREN
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI CONDITION SEMI FOR_INIT | i                    | FOR_INIT -> ASSIGNMENT
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI CONDITION SEMI ASSIGNMENT | i                    | ASSIGNMENT -> ID ASSIGN EXPRESSION
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI CONDITION SEMI EXPRESSION ASSIGN ID | i                    | Ler ID
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI CONDITION SEMI EXPRESSION ASSIGN | =                    | Ler ASSIGN
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI CONDITION SEMI EXPRESSION | 0                    | EXPRESSION -> TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI CONDITION SEMI EXP_PRIME TERM | 0                    | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI CONDITION SEMI EXP_PRIME TERM_PRIME FACTOR | 0                    | FACTOR -> NUMBER
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI CONDITION SEMI EXP_PRIME TERM_PRIME NUMBER | 0                    | Ler NUMBER
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI CONDITION SEMI EXP_PRIME TERM_PRIME | ;                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI CONDITION SEMI EXP_PRIME EPSILON | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI CONDITION SEMI EXP_PRIME | ;                    | EXP_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI CONDITION SEMI EPSILON | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI CONDITION SEMI | ;                    | Ler SEMI
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI CONDITION | i                    | CONDITION -> LOGICAL_OR_EXPR
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI LOGICAL_OR_EXPR | i                    | LOGICAL_OR_EXPR -> LOGICAL_AND_EXPR LOGICAL_OR_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI LOGICAL_OR_PRIME LOGICAL_AND_EXPR | i                    | LOGICAL_AND_EXPR -> RELATIONAL_EXPR LOGICAL_AND_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_EXPR | i                    | RELATIONAL_EXPR -> EXPRESSION RELATIONAL_TAIL
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXPRESSION | i                    | EXPRESSION -> TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXP_PRIME TERM | i                    | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXP_PRIME TERM_PRIME FACTOR | i                    | FACTOR -> ID
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXP_PRIME TERM_PRIME ID | i                    | Ler ID
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXP_PRIME TERM_PRIME | <                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXP_PRIME EPSILON | <                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXP_PRIME | <                    | EXP_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EPSILON | <                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL | <                    | RELATIONAL_TAIL -> LT EXPRESSION
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXPRESSION LT | <                    | Ler LT
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXPRESSION | 5                    | EXPRESSION -> TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXP_PRIME TERM | 5                    | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXP_PRIME TERM_PRIME FACTOR | 5                    | FACTOR -> NUMBER
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXP_PRIME TERM_PRIME NUMBER | 5                    | Ler NUMBER
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXP_PRIME TERM_PRIME | ;                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXP_PRIME EPSILON | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXP_PRIME | ;                    | EXP_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI LOGICAL_OR_PRIME LOGICAL_AND_PRIME EPSILON | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI LOGICAL_OR_PRIME LOGICAL_AND_PRIME | ;                    | LOGICAL_AND_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI LOGICAL_OR_PRIME EPSILON | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN FOR_UPDATE SEMI LOGICAL_OR_PRIME | ;                    | LOGICAL_OR_PRIME -> EPSILON
# ...
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN EPSILON  | )                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN          | )                    | Ler RPAREN
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY                 | {                    | Ler LCURLY
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST                        | x                    | STATEMENT_LIST -> STATEMENT STATEMENT_LIST
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST STATEMENT              | x                    | STATEMENT -> STATEMENT_ID_START
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST STATEMENT_ID_START     | x                    | STATEMENT_ID_START -> ID STATEMENT_ID_TAIL
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST STATEMENT_ID_TAIL ID   | x                    | Ler ID
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST STATEMENT_ID_TAIL      | =                    | STATEMENT_ID_TAIL -> ASSIGN EXPRESSION SEMI
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXPRESSION ASSIGN | =                    | Ler ASSIGN
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXPRESSION        | x                    | EXPRESSION -> TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM    | x                    | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME FACTOR | x                    | FACTOR -> ID
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME ID | x                    | Ler ID
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME | *                    | TERM_PRIME -> MULT FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME FACTOR MULT | *                    | Ler MULT
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME FACTOR | 2                    | FACTOR -> NUMBER
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME NUMBER | 2                    | Ler NUMBER
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME | ;                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME EPSILON | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME         | ;                    | EXP_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EPSILON           | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI                   | ;                    | Ler SEMI
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST                        | }                    | STATEMENT_LIST -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY EPSILON                               | }                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY                                       | }                    | Ler RCURLY
# EOF RCURLY STATEMENT_LIST                                              | switch               | STATEMENT_LIST -> STATEMENT STATEMENT_LIST
# EOF RCURLY STATEMENT_LIST STATEMENT                                    | switch               | STATEMENT -> SWITCH_STATEMENT
# EOF RCURLY STATEMENT_LIST SWITCH_STATEMENT                             | switch               | SWITCH_STATEMENT -> SWITCH LPAREN EXPRESSION RPAREN LCURLY CASE_LIST RCURLY
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST LCURLY RPAREN EXPRESSION LPAREN SWITCH | switch               | Ler SWITCH
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST LCURLY RPAREN EXPRESSION LPAREN | (                    | Ler LPAREN
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST LCURLY RPAREN EXPRESSION    | a                    | EXPRESSION -> TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST LCURLY RPAREN EXP_PRIME TERM | a                    | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST LCURLY RPAREN EXP_PRIME TERM_PRIME FACTOR | a                    | FACTOR -> ID
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST LCURLY RPAREN EXP_PRIME TERM_PRIME ID | a                    | Ler ID
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST LCURLY RPAREN EXP_PRIME TERM_PRIME | )                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST LCURLY RPAREN EXP_PRIME EPSILON | )                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST LCURLY RPAREN EXP_PRIME     | )                    | EXP_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST LCURLY RPAREN EPSILON       | )                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST LCURLY RPAREN               | )                    | Ler RPAREN
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST LCURLY                      | {                    | Ler LCURLY
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST                             | case                 | CASE_LIST -> CASE LITERAL COLON STATEMENT_LIST BREAK SEMI CASE_LIST
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST COLON LITERAL CASE | case                 | Ler CASE
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST COLON LITERAL | 10                   | LITERAL -> NUMBER
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST COLON NUMBER | 10                   | Ler NUMBER
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST COLON | :                    | Ler COLON
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST   | msg                  | STATEMENT_LIST -> STATEMENT STATEMENT_LIST
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST STATEMENT | msg                  | STATEMENT -> STATEMENT_ID_START
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST STATEMENT_ID_START | msg                  | STATEMENT_ID_START -> ID STATEMENT_ID_TAIL
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST STATEMENT_ID_TAIL ID | msg                  | Ler ID
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST STATEMENT_ID_TAIL | =                    | STATEMENT_ID_TAIL -> ASSIGN EXPRESSION SEMI
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST SEMI EXPRESSION ASSIGN | =                    | Ler ASSIGN
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST SEMI EXPRESSION | "valor 10"           | EXPRESSION -> TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST SEMI EXP_PRIME TERM | "valor 10"           | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME FACTOR | "valor 10"           | FACTOR -> STRING_LITERAL
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME STRING_LITERAL | "valor 10"           | Ler STRING_LITERAL
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME | ;                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST SEMI EXP_PRIME EPSILON | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST SEMI EXP_PRIME | ;                    | EXP_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST SEMI EPSILON | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST SEMI | ;                    | Ler SEMI
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST   | break                | STATEMENT_LIST -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK EPSILON          | break                | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK                  | break                | Ler BREAK
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI                        | ;                    | Ler SEMI
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST                             | case                 | CASE_LIST -> CASE LITERAL COLON STATEMENT_LIST BREAK SEMI CASE_LIST
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST COLON LITERAL CASE | case                 | Ler CASE
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST COLON LITERAL | 15                   | LITERAL -> NUMBER
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST COLON NUMBER | 15                   | Ler NUMBER
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST COLON | :                    | Ler COLON
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST   | msg                  | STATEMENT_LIST -> STATEMENT STATEMENT_LIST
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST STATEMENT | msg                  | STATEMENT -> STATEMENT_ID_START
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST STATEMENT_ID_START | msg                  | STATEMENT_ID_START -> ID STATEMENT_ID_TAIL
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST STATEMENT_ID_TAIL ID | msg                  | Ler ID
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST STATEMENT_ID_TAIL | =                    | STATEMENT_ID_TAIL -> ASSIGN EXPRESSION SEMI
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST SEMI EXPRESSION ASSIGN | =                    | Ler ASSIGN
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST SEMI EXPRESSION | "valor 15"           | EXPRESSION -> TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST SEMI EXP_PRIME TERM | "valor 15"           | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME FACTOR | "valor 15"           | FACTOR -> STRING_LITERAL
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME STRING_LITERAL | "valor 15"           | Ler STRING_LITERAL
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME | ;                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST SEMI EXP_PRIME EPSILON | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST SEMI EXP_PRIME | ;                    | EXP_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST SEMI EPSILON | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST SEMI | ;                    | Ler SEMI
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK STATEMENT_LIST   | break                | STATEMENT_LIST -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK EPSILON          | break                | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI BREAK                  | break                | Ler BREAK
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST SEMI                        | ;                    | Ler SEMI
# EOF RCURLY STATEMENT_LIST RCURLY CASE_LIST                             | default              | CASE_LIST -> DEFAULT COLON STATEMENT_LIST BREAK SEMI
# EOF RCURLY STATEMENT_LIST RCURLY SEMI BREAK STATEMENT_LIST COLON DEFAULT | default              | Ler DEFAULT
# EOF RCURLY STATEMENT_LIST RCURLY SEMI BREAK STATEMENT_LIST COLON       | :                    | Ler COLON
# EOF RCURLY STATEMENT_LIST RCURLY SEMI BREAK STATEMENT_LIST             | msg                  | STATEMENT_LIST -> STATEMENT STATEMENT_LIST
# EOF RCURLY STATEMENT_LIST RCURLY SEMI BREAK STATEMENT_LIST STATEMENT   | msg                  | STATEMENT -> STATEMENT_ID_START
# EOF RCURLY STATEMENT_LIST RCURLY SEMI BREAK STATEMENT_LIST STATEMENT_ID_START | msg                  | STATEMENT_ID_START -> ID STATEMENT_ID_TAIL
# EOF RCURLY STATEMENT_LIST RCURLY SEMI BREAK STATEMENT_LIST STATEMENT_ID_TAIL ID | msg                  | Ler ID
# EOF RCURLY STATEMENT_LIST RCURLY SEMI BREAK STATEMENT_LIST STATEMENT_ID_TAIL | =                    | STATEMENT_ID_TAIL -> ASSIGN EXPRESSION SEMI
# EOF RCURLY STATEMENT_LIST RCURLY SEMI BREAK STATEMENT_LIST SEMI EXPRESSION ASSIGN | =                    | Ler ASSIGN
# EOF RCURLY STATEMENT_LIST RCURLY SEMI BREAK STATEMENT_LIST SEMI EXPRESSION | "outro valor"        | EXPRESSION -> TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY SEMI BREAK STATEMENT_LIST SEMI EXP_PRIME TERM | "outro valor"        | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY SEMI BREAK STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME FACTOR | "outro valor"        | FACTOR -> STRING_LITERAL
# EOF RCURLY STATEMENT_LIST RCURLY SEMI BREAK STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME STRING_LITERAL | "outro valor"        | Ler STRING_LITERAL
# EOF RCURLY STATEMENT_LIST RCURLY SEMI BREAK STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME | ;                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY SEMI BREAK STATEMENT_LIST SEMI EXP_PRIME EPSILON | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY SEMI BREAK STATEMENT_LIST SEMI EXP_PRIME | ;                    | EXP_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY SEMI BREAK STATEMENT_LIST SEMI EPSILON | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY SEMI BREAK STATEMENT_LIST SEMI        | ;                    | Ler SEMI
# EOF RCURLY STATEMENT_LIST RCURLY SEMI BREAK STATEMENT_LIST             | break                | STATEMENT_LIST -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY SEMI BREAK EPSILON                    | break                | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY SEMI BREAK                            | break                | Ler BREAK
# EOF RCURLY STATEMENT_LIST RCURLY SEMI                                  | ;                    | Ler SEMI
# EOF RCURLY STATEMENT_LIST RCURLY                                       | }                    | Ler RCURLY
# EOF RCURLY STATEMENT_LIST                                              | return               | STATEMENT_LIST -> STATEMENT STATEMENT_LIST
# EOF RCURLY STATEMENT_LIST STATEMENT                                    | return               | STATEMENT -> RETURN_STATEMENT
# EOF RCURLY STATEMENT_LIST RETURN_STATEMENT                             | return               | RETURN_STATEMENT -> RETURN RETURN_TAIL
# EOF RCURLY STATEMENT_LIST RETURN_TAIL RETURN                           | return               | Ler RETURN
# EOF RCURLY STATEMENT_LIST RETURN_TAIL                                  | a                    | RETURN_TAIL -> EXPRESSION SEMI
# EOF RCURLY STATEMENT_LIST SEMI EXPRESSION                              | a                    | EXPRESSION -> TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM                          | a                    | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME FACTOR             | a                    | FACTOR -> ID
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME ID                 | a                    | Ler ID
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME                    | ;                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME EPSILON                       | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME                               | ;                    | EXP_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST SEMI EPSILON                                 | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST SEMI                                         | ;                    | Ler SEMI
# EOF RCURLY STATEMENT_LIST                                              | }                    | STATEMENT_LIST -> EPSILON
# EOF RCURLY EPSILON                                                     | }                    | Epsilon
# EOF RCURLY                                                             | }                    | Ler RCURLY
# EOF                                                                    | $                    | SUCESSO: ACEITO

# %%
# ==============================================================================
# 2. ❌ ERRO SINTÁTICO: Esperado SEMI(;), encontrado x
# ==============================================================================
if __name__ == "__main__":

    codigo_teste = """
    main() {
        int x = 10
        x = x + 1;
    }
    """

    print("=== 1. LEXER ===")
    lexer = Lexer(codigo_teste)
    tokens = lexer.tokenize()
    print("Tokens OK.")

    print("\n=== 2. TABLE ===")
    compute_first()
    compute_follow()
    build_parsing_table()
    print("Tabela OK.")

    print("\n=== 3. PARSER ===")
    parse(tokens)
# Out:
# === 1. LEXER ===
# Tokens OK.
#
# === 2. TABLE ===
# Tabela OK.
#
# === 3. PARSER ===
#
# PILHA                                                                  | ENTRADA              | AÇÃO
# --------------------------------------------------------------------------------------------------------------
# PROGRAM                                                                | main                 | PROGRAM -> MAIN_FUNCTION EOF
# EOF MAIN_FUNCTION                                                      | main                 | MAIN_FUNCTION -> MAIN LPAREN RPAREN LCURLY STATEMENT_LIST RCURLY
# EOF RCURLY STATEMENT_LIST LCURLY RPAREN LPAREN MAIN                    | main                 | Ler MAIN
# EOF RCURLY STATEMENT_LIST LCURLY RPAREN LPAREN                         | (                    | Ler LPAREN
# EOF RCURLY STATEMENT_LIST LCURLY RPAREN                                | )                    | Ler RPAREN
# EOF RCURLY STATEMENT_LIST LCURLY                                       | {                    | Ler LCURLY
# EOF RCURLY STATEMENT_LIST                                              | int                  | STATEMENT_LIST -> STATEMENT STATEMENT_LIST
# EOF RCURLY STATEMENT_LIST STATEMENT                                    | int                  | STATEMENT -> DECLARATION
# EOF RCURLY STATEMENT_LIST DECLARATION                                  | int                  | DECLARATION -> TYPE ID DECLARATION_TAIL
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL ID TYPE                     | int                  | TYPE -> INT
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL ID INT                      | int                  | Ler INT
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL ID                          | x                    | Ler ID
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL                             | =                    | DECLARATION_TAIL -> ASSIGN EXPRESSION SEMI
# EOF RCURLY STATEMENT_LIST SEMI EXPRESSION ASSIGN                       | =                    | Ler ASSIGN
# EOF RCURLY STATEMENT_LIST SEMI EXPRESSION                              | 10                   | EXPRESSION -> TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM                          | 10                   | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME FACTOR             | 10                   | FACTOR -> NUMBER
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME NUMBER             | 10                   | Ler NUMBER
#
# ERRO: Sem regra para TERM_PRIME com ID

# %%
# ==============================================================================
# 3. ❌ ERRO SINTÁTICO: Faltou } antes do EOF
# ==============================================================================
if __name__ == "__main__":

    codigo_teste = """
    main() {
        int x = 10;

        while (x < 5) {
            x = x + 1;
    """

    print("=== 1. LEXER ===")
    lexer = Lexer(codigo_teste)
    tokens = lexer.tokenize()
    print("Tokens OK.")

    print("\n=== 2. TABLE ===")
    compute_first()
    compute_follow()
    build_parsing_table()
    print("Tabela OK.")

    print("\n=== 3. PARSER ===")
    parse(tokens)
# Out:
# === 1. LEXER ===
# Tokens OK.
#
# === 2. TABLE ===
# Tabela OK.
#
# === 3. PARSER ===
#
# PILHA                                                                  | ENTRADA              | AÇÃO
# --------------------------------------------------------------------------------------------------------------
# PROGRAM                                                                | main                 | PROGRAM -> MAIN_FUNCTION EOF
# EOF MAIN_FUNCTION                                                      | main                 | MAIN_FUNCTION -> MAIN LPAREN RPAREN LCURLY STATEMENT_LIST RCURLY
# EOF RCURLY STATEMENT_LIST LCURLY RPAREN LPAREN MAIN                    | main                 | Ler MAIN
# EOF RCURLY STATEMENT_LIST LCURLY RPAREN LPAREN                         | (                    | Ler LPAREN
# EOF RCURLY STATEMENT_LIST LCURLY RPAREN                                | )                    | Ler RPAREN
# EOF RCURLY STATEMENT_LIST LCURLY                                       | {                    | Ler LCURLY
# EOF RCURLY STATEMENT_LIST                                              | int                  | STATEMENT_LIST -> STATEMENT STATEMENT_LIST
# EOF RCURLY STATEMENT_LIST STATEMENT                                    | int                  | STATEMENT -> DECLARATION
# EOF RCURLY STATEMENT_LIST DECLARATION                                  | int                  | DECLARATION -> TYPE ID DECLARATION_TAIL
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL ID TYPE                     | int                  | TYPE -> INT
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL ID INT                      | int                  | Ler INT
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL ID                          | x                    | Ler ID
# EOF RCURLY STATEMENT_LIST DECLARATION_TAIL                             | =                    | DECLARATION_TAIL -> ASSIGN EXPRESSION SEMI
# EOF RCURLY STATEMENT_LIST SEMI EXPRESSION ASSIGN                       | =                    | Ler ASSIGN
# EOF RCURLY STATEMENT_LIST SEMI EXPRESSION                              | 10                   | EXPRESSION -> TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM                          | 10                   | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME FACTOR             | 10                   | FACTOR -> NUMBER
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME NUMBER             | 10                   | Ler NUMBER
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME                    | ;                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME EPSILON                       | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST SEMI EXP_PRIME                               | ;                    | EXP_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST SEMI EPSILON                                 | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST SEMI                                         | ;                    | Ler SEMI
# EOF RCURLY STATEMENT_LIST                                              | while                | STATEMENT_LIST -> STATEMENT STATEMENT_LIST
# EOF RCURLY STATEMENT_LIST STATEMENT                                    | while                | STATEMENT -> WHILE_STATEMENT
# EOF RCURLY STATEMENT_LIST WHILE_STATEMENT                              | while                | WHILE_STATEMENT -> WHILE LPAREN CONDITION RPAREN LCURLY STATEMENT_LIST RCURLY
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN CONDITION LPAREN WHILE | while                | Ler WHILE
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN CONDITION LPAREN | (                    | Ler LPAREN
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN CONDITION | x                    | CONDITION -> LOGICAL_OR_EXPR
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_EXPR | x                    | LOGICAL_OR_EXPR -> LOGICAL_AND_EXPR LOGICAL_OR_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_EXPR | x                    | LOGICAL_AND_EXPR -> RELATIONAL_EXPR LOGICAL_AND_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_EXPR | x                    | RELATIONAL_EXPR -> EXPRESSION RELATIONAL_TAIL
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXPRESSION | x                    | EXPRESSION -> TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXP_PRIME TERM | x                    | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXP_PRIME TERM_PRIME FACTOR | x                    | FACTOR -> ID
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXP_PRIME TERM_PRIME ID | x                    | Ler ID
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXP_PRIME TERM_PRIME | <                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXP_PRIME EPSILON | <                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EXP_PRIME | <                    | EXP_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL EPSILON | <                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME RELATIONAL_TAIL | <                    | RELATIONAL_TAIL -> LT EXPRESSION
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXPRESSION LT | <                    | Ler LT
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXPRESSION | 5                    | EXPRESSION -> TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXP_PRIME TERM | 5                    | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXP_PRIME TERM_PRIME FACTOR | 5                    | FACTOR -> NUMBER
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXP_PRIME TERM_PRIME NUMBER | 5                    | Ler NUMBER
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXP_PRIME TERM_PRIME | )                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXP_PRIME EPSILON | )                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EXP_PRIME | )                    | EXP_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME EPSILON | )                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME LOGICAL_AND_PRIME | )                    | LOGICAL_AND_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME EPSILON | )                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN LOGICAL_OR_PRIME | )                    | LOGICAL_OR_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN EPSILON  | )                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY RPAREN          | )                    | Ler RPAREN
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST LCURLY                 | {                    | Ler LCURLY
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST                        | x                    | STATEMENT_LIST -> STATEMENT STATEMENT_LIST
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST STATEMENT              | x                    | STATEMENT -> STATEMENT_ID_START
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST STATEMENT_ID_START     | x                    | STATEMENT_ID_START -> ID STATEMENT_ID_TAIL
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST STATEMENT_ID_TAIL ID   | x                    | Ler ID
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST STATEMENT_ID_TAIL      | =                    | STATEMENT_ID_TAIL -> ASSIGN EXPRESSION SEMI
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXPRESSION ASSIGN | =                    | Ler ASSIGN
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXPRESSION        | x                    | EXPRESSION -> TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM    | x                    | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME FACTOR | x                    | FACTOR -> ID
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME ID | x                    | Ler ID
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME | +                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME EPSILON | +                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME         | +                    | EXP_PRIME -> PLUS TERM EXP_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM PLUS | +                    | Ler PLUS
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM    | 1                    | TERM -> FACTOR TERM_PRIME
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME FACTOR | 1                    | FACTOR -> NUMBER
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME NUMBER | 1                    | Ler NUMBER
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME TERM_PRIME | ;                    | TERM_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME EPSILON | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EXP_PRIME         | ;                    | EXP_PRIME -> EPSILON
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI EPSILON           | ;                    | Epsilon
# EOF RCURLY STATEMENT_LIST RCURLY STATEMENT_LIST SEMI                   | ;                    | Ler SEMI
#
# ERRO: Sem regra para STATEMENT_LIST com EOF

# %%
# ==============================================================================
# 4. ❌ ERRO LÉXICO: caractere inesperado $
# ==============================================================================
if __name__ == "__main__":

    codigo_teste = """
    main() {
        int x = 10;
        x = x $ 2;
    }
    """

    print("=== 1. LEXER ===")
    lexer = Lexer(codigo_teste)
    tokens = lexer.tokenize()
    print("Tokens OK.")

    print("\n=== 2. TABLE ===")
    compute_first()
    compute_follow()
    build_parsing_table()
    print("Tabela OK.")

    print("\n=== 3. PARSER ===")
    parse(tokens)
# Out:
# === 1. LEXER ===
# ERRO LÉXICO: Caractere inesperado '$' na linha 4
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
